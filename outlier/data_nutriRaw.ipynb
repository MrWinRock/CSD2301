# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nutri = pd.read_csv('nutriRaw.csv')

# %%
nutri.head()
# Out:
#    Unnamed: 0  gender  situation  tea  coffee  height  weight  age  meat  \
# 0           0       2          1    0       0     151      58   72     4
# 1           1       2          1    1       1     162      60   68     5
# 2           2       2          1    0       4     162      75   78     3
# 3           3       2          1    0       0     154      45   91     0
# 4           4       2          1    2       1     154      50   65     5
#
#    fish  raw_fruit  cooked_fruit_veg  chocol  fat
# 0     3          1                 4       5    6
# 1     2          5                 5       1    4
# 2     1          5                 2       5    4
# 3     4          4                 0       3    2
# 4     3          5                 5       3    2

# %%
nutri.drop(axis=1, columns='Unnamed: 0', inplace=True)

# %%
nutri.head(5)
# Out:
#    gender  situation  tea  coffee  height  weight  age  meat  fish  raw_fruit  \
# 0       2          1    0       0     151      58   72     4     3          1
# 1       2          1    1       1     162      60   68     5     2          5
# 2       2          1    0       4     162      75   78     3     1          5
# 3       2          1    0       0     154      45   91     0     4          4
# 4       2          1    2       1     154      50   65     5     3          5
#
#    cooked_fruit_veg  chocol  fat
# 0                 4       5    6
# 1                 5       1    4
# 2                 2       5    4
# 3                 0       3    2
# 4                 5       3    2

# %%
nutri.shape
# Out:
# (226, 13)

# %%
nutri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            226 non-null    int64
#  1   situation         226 non-null    int64
#  2   tea               226 non-null    int64
#  3   coffee            226 non-null    int64
#  4   height            226 non-null    int64
#  5   weight            226 non-null    int64
#  6   age               226 non-null    int64
#  7   meat              226 non-null    int64
#  8   fish              226 non-null    int64
#  9   raw_fruit         226 non-null    int64
#  10  cooked_fruit_veg  226 non-null    int64
#  11  chocol            226 non-null    int64
#  12  fat               226 non-null    int64
# dtypes: int64(13)
# memory usage: 23.1 KB

# %%
dictGender = {1: 'Male', 2: 'Female'}
# dictSituation = {1: 'Single', 2: 'Living with spouse', 3: 'Living with family', 4: 'Living with soneone else'}
# dictMeat = {0: 'Never', 1: 'Less than once a week', 2: 'Once a week', 3: '2-3 times a week', 4: '4-6 times a week', 5: 'Every day'}
# dictFish = {0: 'Never', 1: 'Less than once a week', 2: 'Once a week', 3: '2-3 times a week', 4: '4-6 times a week', 5: 'Every day'}
# dictRawFruit = {0: 'Never', 1: 'Less than once a week', 2: 'Once a week', 3: '2-3 times a week', 4: '4-6 times a week', 5: 'Every day'}
# dictCookedFruitVeg = {0: 'Never', 1: 'Less than once a week', 2: 'Once a week', 3: '2-3 times a week', 4: '4-6 times a week', 5: 'Every day'}
# dictChocol = {0: 'Never', 1: 'Less than once a week', 2: 'Once a week', 3: '2-3 times a week', 4: '4-6 times a week', 5: 'Every day'}
# dictFat = {1: 'Butter', 2: 'Margarine', 3: 'Peanut oil', 4: 'Sunflower', 5: 'Oilve oil', 6: 'Mix of vegetable', 7: 'Colza oil', 8: 'Duck or goose fat'}

# %%
nutri['gender'] = nutri['gender'].replace(dictGender).astype('category')
# nutri['situation'] = nutri['situation'].replace(dictSituation).astype('category')
# nutri['meat'] = nutri['meat'].replace(dictMeat).astype('category')
# nutri['fish'] = nutri['fish'].replace(dictFish).astype('category')
# nutri['raw_fruit'] = nutri['raw_fruit'].replace(dictRawFruit).astype('category')
# nutri['cooked_fruit_veg'] = nutri['cooked_fruit_veg'].replace(dictCookedFruitVeg).astype('category')
# nutri['chocol'] = nutri['chocol'].replace(dictChocol).astype('category')
# nutri['fat'] = nutri['fat'].replace(dictFat).astype('category')

nutri.head(1)
# Out:
#    gender  situation  tea  coffee  height  weight  age  meat  fish  raw_fruit  \
# 0  Female          1    0       0     151      58   72     4     3          1
#
#    cooked_fruit_veg  chocol  fat
# 0                 4       5    6

# %%
nutri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            226 non-null    category
#  1   situation         226 non-null    int64
#  2   tea               226 non-null    int64
#  3   coffee            226 non-null    int64
#  4   height            226 non-null    int64
#  5   weight            226 non-null    int64
#  6   age               226 non-null    int64
#  7   meat              226 non-null    int64
#  8   fish              226 non-null    int64
#  9   raw_fruit         226 non-null    int64
#  10  cooked_fruit_veg  226 non-null    int64
#  11  chocol            226 non-null    int64
#  12  fat               226 non-null    int64
# dtypes: category(1), int64(12)
# memory usage: 21.7 KB

# %%
unique_counts = pd.DataFrame.from_records([(col, nutri[col].nunique()) for col in nutri.columns],
                          columns=['Column_Name', 'Unique_Count']).sort_values(by=['Unique_Count'])

# %%
unique_counts
# Out:
#          Column_Name  Unique_Count
# 0             gender             2
# 1          situation             3
# 3             coffee             6
# 7               meat             6
# 8               fish             6
# 9          raw_fruit             6
# 10  cooked_fruit_veg             6
# 11            chocol             6
# 12               fat             8
# 2                tea             9
# 6                age            27
# 4             height            37
# 5             weight            50

# %%
nutri['BinningSituation'] = pd.cut(nutri['situation'], bins=4)

# %%
nutri['BinningSituation']
# Out:
# 0      (0.998, 1.5]
# 1      (0.998, 1.5]
# 2      (0.998, 1.5]
# 3      (0.998, 1.5]
# 4      (0.998, 1.5]
#            ...
# 221    (0.998, 1.5]
# 222      (1.5, 2.0]
# 223      (1.5, 2.0]
# 224    (0.998, 1.5]
# 225      (1.5, 2.0]
# Name: BinningSituation, Length: 226, dtype: category
# Categories (4, interval[float64, right]): [(0.998, 1.5] < (1.5, 2.0] < (2.0, 2.5] < (2.5, 3.0]]

# %%
nutri['BinningSituation_1'] = pd.cut(nutri['situation'], bins=4, labels=['Single', 'Living with spouse', 'Living with family', 'Living with soneone else'])

# %%
nutri.head(10)
# Out:
#    gender  situation  tea  coffee  height  weight  age  meat  fish  raw_fruit  \
# 0  Female          1    0       0     151      58   72     4     3          1
# 1  Female          1    1       1     162      60   68     5     2          5
# 2  Female          1    0       4     162      75   78     3     1          5
# 3  Female          1    0       0     154      45   91     0     4          4
# 4  Female          1    2       1     154      50   65     5     3          5
# 5  Female          1    2       0     159      66   82     4     2          5
# 6  Female          1    2       0     160      66   74     3     3          5
# 7  Female          1    0       2     163      66   73     4     2          5
# 8  Female          1    0       3     154      60   89     4     3          5
# 9  Female          1    0       2     160      77   87     2     3          5
#
#    cooked_fruit_veg  chocol  fat BinningSituation BinningSituation_1
# ...

# %%
nutri['BinningSituation_1'].value_counts().plot(kind='barh')
plt.show()

# %%
nutri['BinningMeat'] = pd.cut(nutri['meat'], bins=6, labels=['Never', 'Less than once a week', 'Once a week', '2-3 times a week', '4-6 times a week', 'Every day'])
nutri['BinningFish'] = pd.cut(nutri['fish'], bins=6, labels=['Never', 'Less than once a week', 'Once a week', '2-3 times a week', '4-6 times a week', 'Every day'])
nutri['BinningRawFruit'] = pd.cut(nutri['raw_fruit'], bins=6, labels=['Never', 'Less than once a week', 'Once a week', '2-3 times a week', '4-6 times a week', 'Every day'])
nutri['BinningCookedFruitVeg'] = pd.cut(nutri['cooked_fruit_veg'], bins=6, labels=['Never', 'Less than once a week', 'Once a week', '2-3 times a week', '4-6 times a week', 'Every day'])
nutri['BinningChocol'] = pd.cut(nutri['chocol'], bins=6, labels=['Never', 'Less than once a week', 'Once a week', '2-3 times a week', '4-6 times a week', 'Every day'])
nutri['BingningFat'] = pd.cut(nutri['fat'], bins=8, labels=['Butter', 'Margarine', 'Peanut oil', 'Sunflower oil', 'Oilve oil', 'Mix of vegetable', 'Colza oil', 'Duck or goose fat'])

# %%
nutri.head(10)
# Out:
#    gender  situation  tea  coffee  height  weight  age  meat  fish  raw_fruit  \
# 0  Female          1    0       0     151      58   72     4     3          1
# 1  Female          1    1       1     162      60   68     5     2          5
# 2  Female          1    0       4     162      75   78     3     1          5
# 3  Female          1    0       0     154      45   91     0     4          4
# 4  Female          1    2       1     154      50   65     5     3          5
# 5  Female          1    2       0     159      66   82     4     2          5
# 6  Female          1    2       0     160      66   74     3     3          5
# 7  Female          1    0       2     163      66   73     4     2          5
# 8  Female          1    0       3     154      60   89     4     3          5
# 9  Female          1    0       2     160      77   87     2     3          5
#
#    ...  chocol  fat  BinningSituation BinningSituation_1       BinningMeat  \
# ...

# %%
pd.crosstab(nutri.gender, nutri.situation)
# Out:
# situation   1   2  3
# gender
# Female     78  56  7
# Male       20  63  2

# %%
pd.crosstab(nutri.gender, nutri.situation, margins=True)
# Out:
# situation   1    2  3  All
# gender
# Female     78   56  7  141
# Male       20   63  2   85
# All        98  119  9  226

# %%
nutri['coffee'].mean()
# Out:
# 1.6194690265486726

# %%
nutri['coffee'].quantile(q=[0.25, 0.5, 0.75])
# Out:
# 0.25    1.0
# 0.50    2.0
# 0.75    2.0
# Name: coffee, dtype: float64

# %%
nutri['coffee'].var()
# Out:
# 1.5701081612586039

# %%
round(nutri['coffee'].var(), 2)
# Out:
# 1.57

# %%
nutri['coffee'].std()
# Out:
# 1.2530395689117737

# %%
round(nutri['coffee'].std(), 2)
# Out:
# 1.25

# %%
nutri.to_csv('nutriOutput.csv')
