# %%
import pandas as pd

# %% [markdown]
# # **คำถามข้อที่1**

# %%
df = pd.read_csv('data.csv')

# %%
df  = df.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#         0      1       2      3        4       5       6      7     8
# 0     NaN  0.455   0.365    NaN      NaN  0.2245  0.1010  0.150  15.0
# 1       M  0.350   0.265    NaN      NaN     NaN  0.0485    NaN   7.0
# 2       F  0.530   0.420  0.135      NaN  0.2565  0.1415  0.210   9.0
# 3       M  0.440   0.365  0.125   0.5160  0.2155  0.1140    NaN  10.0
# 4       I  0.330   0.255  0.080   0.2050  0.0895     NaN  0.055   7.0
# ...   ...    ...     ...    ...      ...     ...     ...    ...   ...
# 8352    F  0.625   0.485    NaN   1.0945  0.5310  0.2610  0.296  10.0
# 8353    M    NaN   0.555  0.195   1.9485  0.9455  0.3765  0.495  12.0
# 8354    M  3.350  12.265  0.135   0.5160  0.0895  0.0485  0.330   7.0
# 8355    M  0.350   0.265  0.135  12.5160 -0.0895  0.0485  0.330   7.0
# 8356    M  0.450   0.265  0.150   0.5600  0.1895  0.0585  0.330  -7.0
#
# [8357 rows x 9 columns]

# %%
df.shape
# Out:
# (8357, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8357 entries, 0 to 8356
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6687 non-null   object
#  1   1       6687 non-null   float64
#  2   2       6687 non-null   float64
#  3   3       6687 non-null   float64
#  4   4       6687 non-null   float64
#  5   5       6687 non-null   float64
#  6   6       6687 non-null   float64
#  7   7       6687 non-null   float64
#  8   8       6687 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 587.7+ KB

# %%
df.columns = ["Sex", "Length", "Diameter" ,"Height", "Whole weight", "Shucked weight", "Viscera weight", "Shell weight", "Rings"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8357 entries, 0 to 8356
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             6687 non-null   object
#  1   Length          6687 non-null   float64
#  2   Diameter        6687 non-null   float64
#  3   Height          6687 non-null   float64
#  4   Whole weight    6687 non-null   float64
#  5   Shucked weight  6687 non-null   float64
#  6   Viscera weight  6687 non-null   float64
#  7   Shell weight    6687 non-null   float64
#  8   Rings           6687 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 587.7+ KB

# %%
duplicate_df  = df[df.duplicated()]

# %%
duplicate_df.head()
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4177  NaN   0.455     0.365     NaN           NaN          0.2245
# 4178    M   0.350     0.265     NaN           NaN             NaN
# 4179    F   0.530     0.420   0.135           NaN          0.2565
# 4180    M   0.440     0.365   0.125         0.516          0.2155
# 4181    I   0.330     0.255   0.080         0.205          0.0895
#
#       Viscera weight  Shell weight  Rings
# 4177          0.1010         0.150   15.0
# 4178          0.0485           NaN    7.0
# 4179          0.1415         0.210    9.0
# 4180          0.1140           NaN   10.0
# 4181             NaN         0.055    7.0

# %% [markdown]
# # **คำถามข้อที่ 2**

# %%
duplicate_df.shape
# Out:
# (4177, 9)

# %%
df.shape
# Out:
# (8357, 9)

# %%
newdf = df.drop_duplicates()

# %%
newdf.shape
# Out:
# (4180, 9)

# %% [markdown]
# # **คำถามข้อที่ 3**

# %%
newdf.isnull().sum()
# Out:
# Sex               835
# Length            835
# Diameter          835
# Height            835
# Whole weight      835
# Shucked weight    835
# Viscera weight    835
# Shell weight      835
# Rings             835
# dtype: int64

# %%
newdf.isna().sum()
# Out:
# Sex               835
# Length            835
# Diameter          835
# Height            835
# Whole weight      835
# Shucked weight    835
# Viscera weight    835
# Shell weight      835
# Rings             835
# dtype: int64

# %% [markdown]
# # **คำถามข้อที่ 4**

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4180 entries, 0 to 8356
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             3345 non-null   object
#  1   Length          3345 non-null   float64
#  2   Diameter        3345 non-null   float64
#  3   Height          3345 non-null   float64
#  4   Whole weight    3345 non-null   float64
#  5   Shucked weight  3345 non-null   float64
#  6   Viscera weight  3345 non-null   float64
#  7   Shell weight    3345 non-null   float64
#  8   Rings           3345 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 326.6+ KB

# %%
newdf.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  3345.000000  3345.000000  3345.000000   3345.000000     3345.000000
# mean      0.524075     0.410656     0.139640      0.836464        0.363354
# std       0.129604     0.228051     0.042412      0.528809        0.225372
# min       0.075000     0.055000     0.000000      0.002000       -0.089500
# 25%       0.450000     0.350000     0.115000      0.448500        0.188000
# 50%       0.540000     0.425000     0.140000      0.807500        0.339000
# 75%       0.615000     0.480000     0.165000      1.159000        0.504500
# max       3.350000    12.265000     1.130000     12.516000        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     3345.000000   3345.000000  3345.000000
# mean         0.180175      0.236974     9.959641
# std          0.109653      0.138161     3.258296
# min          0.000500      0.001500    -7.000000
# ...

# %%
newdf['Sex'].describe()
# Out:
# count     3345
# unique       3
# top          M
# freq      1220
# Name: Sex, dtype: object

# %%
newdf.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0  NaN   0.455     0.365     NaN           NaN          0.2245
# 1    M   0.350     0.265     NaN           NaN             NaN
# 2    F   0.530     0.420   0.135           NaN          0.2565
# 3    M   0.440     0.365   0.125         0.516          0.2155
# 4    I   0.330     0.255   0.080         0.205          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150   15.0
# 1          0.0485           NaN    7.0
# 2          0.1415         0.210    9.0
# 3          0.1140           NaN   10.0
# 4             NaN         0.055    7.0

# %%
newdf.loc[:, 'Length'] = newdf['Length'].fillna(newdf['Length'].median())

# %%
newdf.loc[:, 'Height'] = newdf['Height'].fillna(newdf['Height'].median())

# %%
newdf.loc[:, 'Rings'] = newdf['Rings'].fillna(newdf['Rings'].median())

# %%
newdf.loc[:, 'Sex'] = newdf.groupby('Rings')['Sex'].transform(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else newdf['Sex'].mode()[0])
)

# %%
newdf.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.140           NaN          0.2245          0.1010
# 1   M   0.350     0.265   0.140           NaN             NaN          0.0485
# 2   F   0.530     0.420   0.135           NaN          0.2565          0.1415
# 3   M   0.440     0.365   0.125         0.516          0.2155          0.1140
# 4   I   0.330     0.255   0.080         0.205          0.0895             NaN
#
#    Shell weight  Rings
# 0         0.150   15.0
# 1           NaN    7.0
# 2         0.210    9.0
# 3           NaN   10.0
# 4         0.055    7.0

# %%
newdf.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4180.000000  3345.000000  4180.000000   3345.000000     3345.000000
# mean      0.527256     0.410656     0.139712      0.836464        0.363354
# std       0.116110     0.228051     0.037939      0.528809        0.225372
# min       0.075000     0.055000     0.000000      0.002000       -0.089500
# 25%       0.475000     0.350000     0.120000      0.448500        0.188000
# 50%       0.540000     0.425000     0.140000      0.807500        0.339000
# 75%       0.595000     0.480000     0.160000      1.159000        0.504500
# max       3.350000    12.265000     1.130000     12.516000        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     3345.000000   3345.000000  4180.000000
# mean         0.180175      0.236974     9.967703
# std          0.109653      0.138161     2.914702
# min          0.000500      0.001500    -7.000000
# ...

# %%
newdf['Sex'].describe()
# Out:
# count     4180
# unique       3
# top          M
# freq      1701
# Name: Sex, dtype: object

# %% [markdown]
# # **คำถาข้อที่ 5**

# %%
dfbin = newdf.copy()

# %%
dfbin['Length'].describe()
# Out:
# count    4180.000000
# mean        0.527256
# std         0.116110
# min         0.075000
# 25%         0.475000
# 50%         0.540000
# 75%         0.595000
# max         3.350000
# Name: Length, dtype: float64

# %%
dfbin['BinningLength'] = pd.qcut(dfbin.Length, q=5, labels=['Very Small', 'Small', 'Medium', 'Large', 'Very Large'])
dfbin['BinningLength']
# Out:
# 0            Small
# 1       Very Small
# 2            Small
# 3       Very Small
# 4       Very Small
#            ...
# 4175    Very Large
# 4176         Small
# 8354    Very Large
# 8355    Very Small
# 8356    Very Small
# Name: BinningLength, Length: 4180, dtype: category
# Categories (5, object): ['Very Small' < 'Small' < 'Medium' < 'Large' < 'Very Large']

# %%
dfbin['BinningLength'].describe()
# Out:
# count      4180
# unique        4
# top       Small
# freq       1657
# Name: BinningLength, dtype: object
